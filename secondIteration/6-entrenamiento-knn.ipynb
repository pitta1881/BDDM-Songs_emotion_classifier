# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_parquet("../data/df_step3.parquet")
# df = pd.read_parquet("../data/df_step3.it2.full.parquet")

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497975 entries, 0 to 497974
# Data columns (total 133 columns):
#  #    Column       Dtype
# ---   ------       -----
#  0    emb_pca_0    float32
#  1    emb_pca_1    float32
#  2    emb_pca_2    float32
#  3    emb_pca_3    float32
#  4    emb_pca_4    float32
#  5    emb_pca_5    float32
#  6    emb_pca_6    float32
#  7    emb_pca_7    float32
#  8    emb_pca_8    float32
#  9    emb_pca_9    float32
#  10   emb_pca_10   float32
#  11   emb_pca_11   float32
#  12   emb_pca_12   float32
#  13   emb_pca_13   float32
#  14   emb_pca_14   float32
#  15   emb_pca_15   float32
#  16   emb_pca_16   float32
#  17   emb_pca_17   float32
#  18   emb_pca_18   float32
#  19   emb_pca_19   float32
#  20   emb_pca_20   float32
#  21   emb_pca_21   float32
#  22   emb_pca_22   float32
#  23   emb_pca_23   float32
#  24   emb_pca_24   float32
#  25   emb_pca_25   float32
#  26   emb_pca_26   float32
#  27   emb_pca_27   float32
#  28   emb_pca_28   float32
#  29   emb_pca_29   float32
#  30   emb_pca_30   float32
#  31   emb_pca_31   float32
#  32   emb_pca_32   float32
#  33   emb_pca_33   float32
#  34   emb_pca_34   float32
#  35   emb_pca_35   float32
#  36   emb_pca_36   float32
#  37   emb_pca_37   float32
#  38   emb_pca_38   float32
#  39   emb_pca_39   float32
#  40   emb_pca_40   float32
#  41   emb_pca_41   float32
#  42   emb_pca_42   float32
#  43   emb_pca_43   float32
#  44   emb_pca_44   float32
#  45   emb_pca_45   float32
#  46   emb_pca_46   float32
#  47   emb_pca_47   float32
#  48   emb_pca_48   float32
#  49   emb_pca_49   float32
#  50   emb_pca_50   float32
#  51   emb_pca_51   float32
#  52   emb_pca_52   float32
#  53   emb_pca_53   float32
#  54   emb_pca_54   float32
#  55   emb_pca_55   float32
#  56   emb_pca_56   float32
#  57   emb_pca_57   float32
#  58   emb_pca_58   float32
#  59   emb_pca_59   float32
#  60   emb_pca_60   float32
#  61   emb_pca_61   float32
#  62   emb_pca_62   float32
#  63   emb_pca_63   float32
#  64   emb_pca_64   float32
#  65   emb_pca_65   float32
#  66   emb_pca_66   float32
#  67   emb_pca_67   float32
#  68   emb_pca_68   float32
#  69   emb_pca_69   float32
#  70   emb_pca_70   float32
#  71   emb_pca_71   float32
#  72   emb_pca_72   float32
#  73   emb_pca_73   float32
#  74   emb_pca_74   float32
#  75   emb_pca_75   float32
#  76   emb_pca_76   float32
#  77   emb_pca_77   float32
#  78   emb_pca_78   float32
#  79   emb_pca_79   float32
#  80   emb_pca_80   float32
#  81   emb_pca_81   float32
#  82   emb_pca_82   float32
#  83   emb_pca_83   float32
#  84   emb_pca_84   float32
#  85   emb_pca_85   float32
#  86   emb_pca_86   float32
#  87   emb_pca_87   float32
#  88   emb_pca_88   float32
#  89   emb_pca_89   float32
#  90   emb_pca_90   float32
#  91   emb_pca_91   float32
#  92   emb_pca_92   float32
#  93   emb_pca_93   float32
#  94   emb_pca_94   float32
#  95   emb_pca_95   float32
#  96   emb_pca_96   float32
#  97   emb_pca_97   float32
#  98   emb_pca_98   float32
#  99   emb_pca_99   float32
#  100  emb_pca_100  float32
#  101  emb_pca_101  float32
#  102  emb_pca_102  float32
#  103  emb_pca_103  float32
#  104  emb_pca_104  float32
#  105  emb_pca_105  float32
#  106  emb_pca_106  float32
#  107  emb_pca_107  float32
#  108  emb_pca_108  float32
#  109  emb_pca_109  float32
#  110  emb_pca_110  float32
#  111  emb_pca_111  float32
#  112  emb_pca_112  float32
#  113  emb_pca_113  float32
#  114  emb_pca_114  float32
#  115  emb_pca_115  float32
#  116  emb_pca_116  float32
#  117  emb_pca_117  float32
#  118  emb_pca_118  float32
#  119  emb_pca_119  float32
#  120  emb_pca_120  float32
#  121  emb_pca_121  float32
#  122  emb_pca_122  float32
#  123  emb_pca_123  float32
#  124  emb_pca_124  float32
#  125  emb_pca_125  float32
#  126  emb_pca_126  float32
#  127  emb_pca_127  float32
#  128  emb_pca_128  float32
#  129  emb_pca_129  float32
#  130  emb_pca_130  float32
#  131  emb_pca_131  float32
#  132  emotion      object
# dtypes: float32(132), object(1)
# memory usage: 254.5+ MB

# %% [markdown]
# # Entrenamiento

# %%
X = df.drop(columns=["emotion"])
y = df["emotion"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %%
knn = KNeighborsClassifier(
    n_neighbors=11,
    weights='distance',
    metric='manhattan',
    leaf_size=20,
    n_jobs=-1
)
knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nReporte de clasificación:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.4838495908429138
#
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#        anger       0.41      0.47      0.44     19096
#         fear       0.47      0.05      0.09      5200
#          joy       0.53      0.53      0.53     37869
#         love       0.46      0.10      0.16      5075
#      sadness       0.49      0.58      0.53     31360
#     surprise       0.66      0.03      0.06       995
#
#     accuracy                           0.48     99595
#    macro avg       0.50      0.29      0.30     99595
# weighted avg       0.49      0.48      0.47     99595
