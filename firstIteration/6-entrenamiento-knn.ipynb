# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import GridSearchCV

# %%
# df = pd.read_parquet("../data/df_step3.parquet")
df = pd.read_parquet("../data/df_step3.full.parquet")

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497975 entries, 0 to 497974
# Data columns (total 269 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    Length                          float64
#  1    emotion                         object
#  2    Tempo                           float64
#  3    Loudness                        float64
#  4    Explicit                        float64
#  5    Popularity                      float64
#  6    Energy                          float64
#  7    Danceability                    float64
#  8    Positiveness                    float64
#  9    Speechiness                     float64
#  10   Liveness                        float64
#  11   Acousticness                    float64
#  12   Instrumentalness                float64
#  13   Good for Party                  float64
#  14   Good for Work/Study             float64
#  15   Good for Relaxation/Meditation  float64
#  16   Good for Exercise               float64
#  17   Good for Running                float64
#  18   Good for Yoga/Stretching        float64
#  19   Good for Driving                float64
#  20   Good for Social Gatherings      float64
#  21   Good for Morning Routine        float64
#  22   acoustic                        float64
#  23   alt-country                     float64
#  24   alternative                     float64
#  25   alternative rock                float64
#  26   ambient                         float64
#  27   black metal                     float64
#  28   blues                           float64
#  29   britpop                         float64
#  30   chillout                        float64
#  31   chillwave                       float64
#  32   christian                       float64
#  33   classic rock                    float64
#  34   classical                       float64
#  35   cloud rap                       float64
#  36   comedy                          float64
#  37   country                         float64
#  38   dance                           float64
#  39   dancehall                       float64
#  40   death metal                     float64
#  41   deathcore                       float64
#  42   disco                           float64
#  43   doom metal                      float64
#  44   dream pop                       float64
#  45   drum and bass                   float64
#  46   dub                             float64
#  47   dubstep                         float64
#  48   electro                         float64
#  49   electronic                      float64
#  50   electropop                      float64
#  51   emo                             float64
#  52   emo rap                         float64
#  53   experimental                    float64
#  54   folk                            float64
#  55   funk                            float64
#  56   garage rock                     float64
#  57   gospel                          float64
#  58   grime                           float64
#  59   grunge                          float64
#  60   hard rock                       float64
#  61   hardcore                        float64
#  62   heavy metal                     float64
#  63   hip hop                         float64
#  64   hip-hop                         float64
#  65   house                           float64
#  66   indie                           float64
#  67   indie pop                       float64
#  68   indie rock                      float64
#  69   industrial                      float64
#  70   j-pop                           float64
#  71   jazz                            float64
#  72   k-pop                           float64
#  73   latin                           float64
#  74   lo-fi                           float64
#  75   math rock                       float64
#  76   melodic death metal             float64
#  77   metal                           float64
#  78   metalcore                       float64
#  79   new wave                        float64
#  80   nu metal                        float64
#  81   pop                             float64
#  82   pop punk                        float64
#  83   pop rock                        float64
#  84   post-hardcore                   float64
#  85   post-punk                       float64
#  86   power metal                     float64
#  87   progressive metal               float64
#  88   progressive rock                float64
#  89   psychedelic                     float64
#  90   psychedelic rock                float64
#  91   punk                            float64
#  92   punk rock                       float64
#  93   rap                             float64
#  94   reggae                          float64
#  95   reggaeton                       float64
#  96   rnb                             float64
#  97   rock                            float64
#  98   screamo                         float64
#  99   shoegaze                        float64
#  100  soul                            float64
#  101  soundtrack                      float64
#  102  swing                           float64
#  103  synthpop                        float64
#  104  techno                          float64
#  105  thrash metal                    float64
#  106  trance                          float64
#  107  trap                            float64
#  108  trip-hop                        float64
#  109  worship                         float64
#  110  Key_A Maj                       float64
#  111  Key_A min                       float64
#  112  Key_A# Maj                      float64
#  113  Key_A# min                      float64
#  114  Key_B Maj                       float64
#  115  Key_B min                       float64
#  116  Key_C Maj                       float64
#  117  Key_C min                       float64
#  118  Key_C# Maj                      float64
#  119  Key_C# min                      float64
#  120  Key_D Maj                       float64
#  121  Key_D min                       float64
#  122  Key_D# Maj                      float64
#  123  Key_D# min                      float64
#  124  Key_E Maj                       float64
#  125  Key_E min                       float64
#  126  Key_F Maj                       float64
#  127  Key_F min                       float64
#  128  Key_F# Maj                      float64
#  129  Key_F# min                      float64
#  130  Key_G Maj                       float64
#  131  Key_G min                       float64
#  132  Key_G# Maj                      float64
#  133  Key_G# min                      float64
#  134  TS_1/4                          float64
#  135  TS_3/4                          float64
#  136  TS_4/4                          float64
#  137  TS_5/4                          float64
#  138  lyric_emb_pca_0                 float32
#  139  lyric_emb_pca_1                 float32
#  140  lyric_emb_pca_2                 float32
#  141  lyric_emb_pca_3                 float32
#  142  lyric_emb_pca_4                 float32
#  143  lyric_emb_pca_5                 float32
#  144  lyric_emb_pca_6                 float32
#  145  lyric_emb_pca_7                 float32
#  146  lyric_emb_pca_8                 float32
#  147  lyric_emb_pca_9                 float32
#  148  lyric_emb_pca_10                float32
#  149  lyric_emb_pca_11                float32
#  150  lyric_emb_pca_12                float32
#  151  lyric_emb_pca_13                float32
#  152  lyric_emb_pca_14                float32
#  153  lyric_emb_pca_15                float32
#  154  lyric_emb_pca_16                float32
#  155  lyric_emb_pca_17                float32
#  156  lyric_emb_pca_18                float32
#  157  lyric_emb_pca_19                float32
#  158  lyric_emb_pca_20                float32
#  159  lyric_emb_pca_21                float32
#  160  lyric_emb_pca_22                float32
#  161  lyric_emb_pca_23                float32
#  162  lyric_emb_pca_24                float32
#  163  lyric_emb_pca_25                float32
#  164  lyric_emb_pca_26                float32
#  165  lyric_emb_pca_27                float32
#  166  lyric_emb_pca_28                float32
#  167  lyric_emb_pca_29                float32
#  168  lyric_emb_pca_30                float32
#  169  lyric_emb_pca_31                float32
#  170  lyric_emb_pca_32                float32
#  171  lyric_emb_pca_33                float32
#  172  lyric_emb_pca_34                float32
#  173  lyric_emb_pca_35                float32
#  174  lyric_emb_pca_36                float32
#  175  lyric_emb_pca_37                float32
#  176  lyric_emb_pca_38                float32
#  177  lyric_emb_pca_39                float32
#  178  lyric_emb_pca_40                float32
#  179  lyric_emb_pca_41                float32
#  180  lyric_emb_pca_42                float32
#  181  lyric_emb_pca_43                float32
#  182  lyric_emb_pca_44                float32
#  183  lyric_emb_pca_45                float32
#  184  lyric_emb_pca_46                float32
#  185  lyric_emb_pca_47                float32
#  186  lyric_emb_pca_48                float32
#  187  lyric_emb_pca_49                float32
#  188  lyric_emb_pca_50                float32
#  189  lyric_emb_pca_51                float32
#  190  lyric_emb_pca_52                float32
#  191  lyric_emb_pca_53                float32
#  192  lyric_emb_pca_54                float32
#  193  lyric_emb_pca_55                float32
#  194  lyric_emb_pca_56                float32
#  195  lyric_emb_pca_57                float32
#  196  lyric_emb_pca_58                float32
#  197  lyric_emb_pca_59                float32
#  198  lyric_emb_pca_60                float32
#  199  lyric_emb_pca_61                float32
#  200  lyric_emb_pca_62                float32
#  201  lyric_emb_pca_63                float32
#  202  lyric_emb_pca_64                float32
#  203  lyric_emb_pca_65                float32
#  204  lyric_emb_pca_66                float32
#  205  lyric_emb_pca_67                float32
#  206  lyric_emb_pca_68                float32
#  207  lyric_emb_pca_69                float32
#  208  lyric_emb_pca_70                float32
#  209  lyric_emb_pca_71                float32
#  210  lyric_emb_pca_72                float32
#  211  lyric_emb_pca_73                float32
#  212  lyric_emb_pca_74                float32
#  213  lyric_emb_pca_75                float32
#  214  lyric_emb_pca_76                float32
#  215  lyric_emb_pca_77                float32
#  216  lyric_emb_pca_78                float32
#  217  lyric_emb_pca_79                float32
#  218  lyric_emb_pca_80                float32
#  219  lyric_emb_pca_81                float32
#  220  lyric_emb_pca_82                float32
#  221  lyric_emb_pca_83                float32
#  222  lyric_emb_pca_84                float32
#  223  lyric_emb_pca_85                float32
#  224  lyric_emb_pca_86                float32
#  225  lyric_emb_pca_87                float32
#  226  lyric_emb_pca_88                float32
#  227  lyric_emb_pca_89                float32
#  228  lyric_emb_pca_90                float32
#  229  lyric_emb_pca_91                float32
#  230  lyric_emb_pca_92                float32
#  231  lyric_emb_pca_93                float32
#  232  lyric_emb_pca_94                float32
#  233  lyric_emb_pca_95                float32
#  234  lyric_emb_pca_96                float32
#  235  lyric_emb_pca_97                float32
#  236  lyric_emb_pca_98                float32
#  237  lyric_emb_pca_99                float32
#  238  lyric_emb_pca_100               float32
#  239  lyric_emb_pca_101               float32
#  240  lyric_emb_pca_102               float32
#  241  lyric_emb_pca_103               float32
#  242  lyric_emb_pca_104               float32
#  243  lyric_emb_pca_105               float32
#  244  lyric_emb_pca_106               float32
#  245  lyric_emb_pca_107               float32
#  246  lyric_emb_pca_108               float32
#  247  lyric_emb_pca_109               float32
#  248  lyric_emb_pca_110               float32
#  249  lyric_emb_pca_111               float32
#  250  lyric_emb_pca_112               float32
#  251  lyric_emb_pca_113               float32
#  252  lyric_emb_pca_114               float32
#  253  lyric_emb_pca_115               float32
#  254  lyric_emb_pca_116               float32
#  255  lyric_emb_pca_117               float32
#  256  lyric_emb_pca_118               float32
#  257  lyric_emb_pca_119               float32
#  258  lyric_emb_pca_120               float32
#  259  lyric_emb_pca_121               float32
#  260  lyric_emb_pca_122               float32
#  261  lyric_emb_pca_123               float32
#  262  lyric_emb_pca_124               float32
#  263  lyric_emb_pca_125               float32
#  264  lyric_emb_pca_126               float32
#  265  lyric_emb_pca_127               float32
#  266  lyric_emb_pca_128               float32
#  267  lyric_emb_pca_129               float32
#  268  lyric_emb_pca_130               float32
# dtypes: float32(131), float64(137), object(1)
# memory usage: 773.1+ MB

# %% [markdown]
# # Entrenamiento

# %%
X = df.drop(columns=["emotion"])
y = df["emotion"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %%
# ONLY FOR COLAB
# param_grid = {
#     'n_neighbors': [3, 5, 7, 9, 11],
#     'weights': ['uniform', 'distance'],
#     'metric': ['euclidean', 'manhattan'],
#     'leaf_size': [20, 30, 40],
# }

# knn = KNeighborsClassifier()

# grid_search = GridSearchCV(
#     estimator=knn,
#     param_grid=param_grid,
#     cv=3,
#     scoring='accuracy',  # se puede omitir, pero es buena práctica especificarlo
#     n_jobs=-1,
#     verbose=1
# )
# grid_search.fit(X_train, y_train)

# %%
# ONLY FOR COLAB
# print("Mejores parámetros encontrados:")
# print(grid_search.best_params_)

# print("Accuracy en test:")
# print(grid_search.score(X_test, y_test))

# %%
# knn = KNeighborsClassifier(
#     n_neighbors=grid_search.best_params_['n_neighbors'],
#     weights=grid_search.best_params_['weights'],
#     metric=grid_search.best_params_['metric'],
#     leaf_size=grid_search.best_params_['leaf_size']
# )
knn = KNeighborsClassifier(
    n_neighbors=11,
    weights='distance',
    metric='manhattan',
    leaf_size=20,
    n_jobs=-1
)
knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nReporte de clasificación:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.4496711682313369
#
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#        anger       0.40      0.40      0.40     19096
#         fear       0.38      0.03      0.05      5200
#          joy       0.48      0.51      0.50     37869
#         love       0.39      0.06      0.10      5075
#      sadness       0.44      0.55      0.49     31360
#     surprise       0.67      0.02      0.04       995
#
#     accuracy                           0.45     99595
#    macro avg       0.46      0.26      0.26     99595
# weighted avg       0.45      0.45      0.43     99595
