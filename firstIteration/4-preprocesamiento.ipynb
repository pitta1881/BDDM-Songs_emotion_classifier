# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_parquet("../data/df_step2.parquet")

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 497975 entries, 0 to 551442
# Data columns (total 139 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    Lyrics                          object
#  1    Length                          float64
#  2    emotion                         object
#  3    Tempo                           float64
#  4    Loudness                        float64
#  5    Explicit                        float64
#  6    Popularity                      float64
#  7    Energy                          float64
#  8    Danceability                    float64
#  9    Positiveness                    float64
#  10   Speechiness                     float64
#  11   Liveness                        float64
#  12   Acousticness                    float64
#  13   Instrumentalness                float64
#  14   Good for Party                  float64
#  15   Good for Work/Study             float64
#  16   Good for Relaxation/Meditation  float64
#  17   Good for Exercise               float64
#  18   Good for Running                float64
#  19   Good for Yoga/Stretching        float64
#  20   Good for Driving                float64
#  21   Good for Social Gatherings      float64
#  22   Good for Morning Routine        float64
#  23   acoustic                        float64
#  24   alt-country                     float64
#  25   alternative                     float64
#  26   alternative rock                float64
#  27   ambient                         float64
#  28   black metal                     float64
#  29   blues                           float64
#  30   britpop                         float64
#  31   chillout                        float64
#  32   chillwave                       float64
#  33   christian                       float64
#  34   classic rock                    float64
#  35   classical                       float64
#  36   cloud rap                       float64
#  37   comedy                          float64
#  38   country                         float64
#  39   dance                           float64
#  40   dancehall                       float64
#  41   death metal                     float64
#  42   deathcore                       float64
#  43   disco                           float64
#  44   doom metal                      float64
#  45   dream pop                       float64
#  46   drum and bass                   float64
#  47   dub                             float64
#  48   dubstep                         float64
#  49   electro                         float64
#  50   electronic                      float64
#  51   electropop                      float64
#  52   emo                             float64
#  53   emo rap                         float64
#  54   experimental                    float64
#  55   folk                            float64
#  56   funk                            float64
#  57   garage rock                     float64
#  58   gospel                          float64
#  59   grime                           float64
#  60   grunge                          float64
#  61   hard rock                       float64
#  62   hardcore                        float64
#  63   heavy metal                     float64
#  64   hip hop                         float64
#  65   hip-hop                         float64
#  66   house                           float64
#  67   indie                           float64
#  68   indie pop                       float64
#  69   indie rock                      float64
#  70   industrial                      float64
#  71   j-pop                           float64
#  72   jazz                            float64
#  73   k-pop                           float64
#  74   latin                           float64
#  75   lo-fi                           float64
#  76   math rock                       float64
#  77   melodic death metal             float64
#  78   metal                           float64
#  79   metalcore                       float64
#  80   new wave                        float64
#  81   nu metal                        float64
#  82   pop                             float64
#  83   pop punk                        float64
#  84   pop rock                        float64
#  85   post-hardcore                   float64
#  86   post-punk                       float64
#  87   power metal                     float64
#  88   progressive metal               float64
#  89   progressive rock                float64
#  90   psychedelic                     float64
#  91   psychedelic rock                float64
#  92   punk                            float64
#  93   punk rock                       float64
#  94   rap                             float64
#  95   reggae                          float64
#  96   reggaeton                       float64
#  97   rnb                             float64
#  98   rock                            float64
#  99   screamo                         float64
#  100  shoegaze                        float64
#  101  soul                            float64
#  102  soundtrack                      float64
#  103  swing                           float64
#  104  synthpop                        float64
#  105  techno                          float64
#  106  thrash metal                    float64
#  107  trance                          float64
#  108  trap                            float64
#  109  trip-hop                        float64
#  110  worship                         float64
#  111  Key_A Maj                       float64
#  112  Key_A min                       float64
#  113  Key_A# Maj                      float64
#  114  Key_A# min                      float64
#  115  Key_B Maj                       float64
#  116  Key_B min                       float64
#  117  Key_C Maj                       float64
#  118  Key_C min                       float64
#  119  Key_C# Maj                      float64
#  120  Key_C# min                      float64
#  121  Key_D Maj                       float64
#  122  Key_D min                       float64
#  123  Key_D# Maj                      float64
#  124  Key_D# min                      float64
#  125  Key_E Maj                       float64
#  126  Key_E min                       float64
#  127  Key_F Maj                       float64
#  128  Key_F min                       float64
#  129  Key_F# Maj                      float64
#  130  Key_F# min                      float64
#  131  Key_G Maj                       float64
#  132  Key_G min                       float64
#  133  Key_G# Maj                      float64
#  134  Key_G# min                      float64
#  135  TS_1/4                          float64
#  136  TS_3/4                          float64
#  137  TS_4/4                          float64
#  138  TS_5/4                          float64
# dtypes: float64(137), object(2)
# memory usage: 531.9+ MB

# %% [markdown]
# # Preprocesamiento 2

# %% [markdown]
# ### Embeddings

# %%
# use a sample of the dataset, or the full dataset
useASample = True
if (useASample):
    df = df.sample(n=1000, random_state=42)

# %%
# Instanciás el modelo preentrenado
model = SentenceTransformer('all-MiniLM-L6-v2')

# Transformás las letras en embeddings
embeddings = model.encode(df['Lyrics'].tolist(), convert_to_tensor=False, show_progress_bar=True)

# Convertís los embeddings a DataFrame
embeddings_df = pd.DataFrame(embeddings, columns=[f'lyric_emb_{i}' for i in range(embeddings.shape[1])])

# Reseteás el índice de ambos DataFrames
df = df.reset_index(drop=True)
embeddings_df = embeddings_df.reset_index(drop=True)

# Concatenás al dataset original (sin la columna Lyrics)
df_final = pd.concat([df.drop(columns=['Lyrics']), embeddings_df], axis=1)

# Mostrás el resultado
df_final.head()
# Out:
# Batches: 100%|██████████| 32/32 [00:09<00:00,  3.27it/s]
# Batches: 100%|██████████| 32/32 [00:09<00:00,  3.27it/s]
# Batches: 100%|██████████| 32/32 [00:09<00:00,  3.27it/s]
# Batches: 100%|██████████| 32/32 [00:09<00:00,  3.27it/s]
#      Length  emotion     Tempo  Loudness  Explicit  Popularity  Energy  \
# 0  0.076535  sadness  0.307692  0.780160       0.0        0.24    0.48
# 1  0.046818     love  0.905325  0.700036       0.0        0.12    0.43
# 2  0.107934  sadness  0.414201  0.804142       0.0        0.35    0.97
# 3  0.044575    anger  0.289941  0.756904       0.0        0.25    0.30
# 4  0.063078  sadness  0.550296  0.782703       0.0        0.50    0.74
#
#    Danceability  Positiveness  Speechiness  ...  lyric_emb_374  lyric_emb_375  \
# 0      0.537634          0.33     0.000000  ...       0.008532       0.039354
# 1      0.193548          0.15     0.031579  ...       0.046552       0.047393
# 2      0.225806          0.21     0.178947  ...       0.024420      -0.035525
# 3      0.688172          0.14     0.021053  ...       0.024856       0.008566
# 4      0.419355          0.13     0.021053  ...       0.024535       0.074215
#
#    lyric_emb_376  lyric_emb_377  lyric_emb_378  lyric_emb_379  lyric_emb_380  \
# 0       0.016848       0.090464      -0.022972      -0.034667       0.015312
# 1       0.028893       0.057109      -0.008307      -0.025344       0.022032
# 2       0.029651       0.076029      -0.000808      -0.007480       0.034198
# 3      -0.037895       0.086845      -0.065897      -0.048799       0.079852
# 4      -0.011271      -0.019083      -0.056985       0.043992       0.033423
#
#    lyric_emb_381  lyric_emb_382  lyric_emb_383
# 0       0.112379      -0.072987      -0.049524
# 1       0.074153      -0.026245      -0.100412
# 2      -0.021866      -0.049595      -0.031475
# 3       0.050016       0.028316      -0.048752
# 4       0.027449       0.004899      -0.051095
#
# [5 rows x 522 columns]

# %% [markdown]
# ### PCA sobre embeddings

# %%
# 1. Inicializamos el PCA para retener el 80% de la varianza
pca = PCA(n_components=0.80, random_state=42)

# 2. Ajustamos y transformamos
lyrics_embeddings_pca = pca.fit_transform(embeddings_df)

# 3. Revisamos cuántos componentes quedaron
print(f"Componentes seleccionados: {pca.n_components_}")
# Out:
# Componentes seleccionados: 109

# %% [markdown]
# ### Normalizar los embeddings PCA

# %%
# Normalizamos los embeddings PCA
scaler = MinMaxScaler()

lyrics_embeddings_pca_normalized = scaler.fit_transform(lyrics_embeddings_pca)

# Convertimos a DataFrame
lyrics_embeddings_pca_normalized_df = pd.DataFrame(lyrics_embeddings_pca_normalized,
                                                    columns=[f'lyric_emb_pca_{i}' for i in range(lyrics_embeddings_pca_normalized.shape[1])])

# Concatenamos al dataset original
df_final_pca = pd.concat([df.drop(columns=['Lyrics']), lyrics_embeddings_pca_normalized_df], axis=1)

# %%
# Guardar el DataFrame modificado en formato eficiente
df_final_pca.to_parquet("../data/df_step3.parquet")

# %% [markdown]
# En el proximo paso se comenzará con los entrenamiento de los modelos RF y KNN
